# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns
import emoji as em
from bs4 import BeautifulSoup

import json
import re
from spellchecker import SpellChecker

# %%
api_key = "AIzaSyC3WWD7ojDKj8jfOyENcuJLftcSdqfyRXQ"
#channel_id = "UC3SdeibuuvF-ganJesKyDVQ"
# channel_ids = ["UCaizTs-t-jXjj8H0-S3ATYA",
#                "UCxladMszXan-jfgzyeIMyvw",
#                "UCJQJAI7IjbLcpsjWdSzYz0Q",
#                "UCNU_lfiiWBdtULKOw6X0Dig"
#               ]


video_ids =  ["SwSbnmqk3zY","rBPQ5fg_kiY", "jXKGsMPk1Hg"]
anime_video_ids = ["goGqVSraxk8", "zKcPIAa8OUA", "LhxbuHG4SQo"]


youtube = build("youtube","v3", developerKey = api_key)

# %%
def get_channel_comments(youtube, video_ids):
    comments = []

    for video_id in video_ids:
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100
        )
       
        
        while request is not None:
            response = request.execute()
            
            for item in response["items"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append([
                    comment["authorDisplayName"],
                    comment["publishedAt"],
                    
                    comment["updatedAt"],
                    comment["likeCount"],
                    
                    comment["textDisplay"]
                ])
                
            request = youtube.commentThreads().list_next(request, response)
    
    df = pd.DataFrame(comments, columns=["author", "published_at", "updated_at", "like_count", "text"])
    return df


df = get_channel_comments(youtube,video_ids)
df.head(20)
# Out:
#                    author          published_at            updated_at  \
# 0   @swarnilakarmakar6585  2024-07-08T16:02:02Z  2024-07-08T16:02:02Z
# 1         @anjumaurya5603  2024-07-08T04:27:41Z  2024-07-08T04:27:41Z
# 2             @DanyalTipu  2024-07-05T12:13:10Z  2024-07-05T12:13:10Z
# 3        @ayushjaiswal350  2024-07-03T08:59:29Z  2024-07-03T08:59:29Z
# 4         @ChristinaK-r6n  2024-06-27T02:37:18Z  2024-06-27T02:37:18Z
# 5             @saloni1148  2024-06-16T07:59:19Z  2024-06-16T07:59:19Z
# 6              @bose19942  2024-06-05T23:27:56Z  2024-06-05T23:27:56Z
# 7      @swarnimsrijan7470  2024-05-16T19:46:59Z  2024-05-16T19:46:59Z
# 8       @deepasinghal4729  2024-05-13T22:04:03Z  2024-05-13T22:04:03Z
# 9        @rahulrajeev9763  2024-04-27T20:24:34Z  2024-04-27T20:24:34Z
# 10         @mohdsaqib3241  2024-04-27T03:46:50Z  2024-04-27T03:46:50Z
# 11        @yankoshuan6225  2024-04-20T19:11:25Z  2024-04-20T19:11:25Z
# 12       @user-uv5lr7bk8n  2024-04-18T02:51:14Z  2024-04-18T02:51:14Z
# 13            @najam00717  2024-04-01T13:19:56Z  2024-04-01T13:19:56Z
# 14             @Abutturab  2024-03-28T08:51:09Z  2024-03-28T08:51:09Z
# 15             @ryang8192  2024-03-21T04:15:06Z  2024-03-21T04:15:06Z
# 16      @VARUNKUMAR-dj6mi  2024-03-04T09:34:34Z  2024-03-04T09:34:34Z
# 17      @VARUNKUMAR-dj6mi  2024-03-04T09:34:25Z  2024-03-04T09:34:25Z
# 18      @VARUNKUMAR-dj6mi  2024-03-04T09:33:19Z  2024-03-04T09:34:14Z
# 19    @internetmaxvui7719  2024-02-28T08:27:57Z  2024-02-28T08:27:57Z
#
#     like_count                                               text
# 0            0  Hello sir, I have tried through the methods u ...
# 1            0  I am getting key error for the commentCount co...
# 2            0  Can someone tell me from where i can get the s...
# 3            0                                       this is good
# 4            0  Thank you for putting this together! It was su...
# 5            0              can i do this project on google colab
# 6            0                           Thank you for this video
# 7            0  what a brilliant lecture! Really impressed by ...
# 8            0  followed till <a href="https://www.youtube.com...
# 9            0                  Thank you so much for this stuff.
# 10           0                          Project link not working!
# 11           0  {&#39;kind&#39;: &#39;youtube<a href="http://w...
# 12           0  for a non-tech background like me, your tutori...
# 13           0      Why the Json is not showing &#39;Likes&#39; ?
# 14           0                                              top !
# 15           1  Hello. i want to ask, how to receive video dat...
# 16           0  <a href="https://www.youtube.com/watch?v=SwSbn...
# 17           0  <a href="https://www.youtube.com/watch?v=SwSbn...
# 18           0  <a href="https://www.youtube.com/watch?v=SwSbn...
# 19           0  Sorry sir, the link project in the description...

# %%
# Data cleaning section

def remove_emojis(text):
    return em.replace_emoji(text, replace='')

def remove_html_tags(text):
    return BeautifulSoup(text, "html.parser").get_text()


def clean_text(comment):
    # Remove paths starting with 'c:\' and onwards, along with subsequent text
    cleaned_comment = re.sub(r'c:\\.*', '', comment)
    
    # Remove portions inside {} brackets, [], and ()
    cleaned_comment = re.sub(r'[\{\[\(].*?[\}\]\)]', '', cleaned_comment)
    
    # Remove specific symbols: $, =, }, {, <, >, #, @
    cleaned_comment = re.sub(r'[\$\=\}\{\<\>\#@]', '', cleaned_comment)
    
    # Remove patterns like ????, !!!!, !!!????, and repeated characters like ...
    cleaned_comment = re.sub(r'(\?{2,15}|!{2,15}|\.{3,15})', '', cleaned_comment)
    
    # Remove HTML tags
    cleaned_comment = re.sub(r'<.*?>', '', cleaned_comment)
    
    # Remove non-alphanumeric characters, underscores, and extra spaces
    cleaned_comment = re.sub(r'[^\w\s]', '', cleaned_comment)
    cleaned_comment = re.sub(r'\s+', ' ', cleaned_comment).strip()
    
    return cleaned_comment.strip()

    




df['text'] = df['text'].str.strip() 
df['text'].fillna("", inplace=True) 
df = df[df['text'] != '']  
df["author"] = df["author"].str[1:]
df
df["published_at"] = df["published_at"].str[0:10]
df["updated_at"] = df["updated_at"].str[0:10]
df["text"] = df["text"].str.lower()
df["text"] = df["text"].apply(remove_emojis)
df["text"] = df["text"].apply(remove_html_tags)
df.tail(200)
df["text"] = df["text"].apply(clean_text)
df.drop_duplicates(subset=['text'], keep='first', inplace=True)
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_3804\2607510833.py:7: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   return BeautifulSoup(text, "html.parser").get_text()

# %%
df.head(20)
# Out:
#                   author published_at  updated_at  like_count  \
# 0   swarnilakarmakar6585   2024-07-08  2024-07-08           0
# 1         anjumaurya5603   2024-07-08  2024-07-08           0
# 2             DanyalTipu   2024-07-05  2024-07-05           0
# 3        ayushjaiswal350   2024-07-03  2024-07-03           0
# 4         ChristinaK-r6n   2024-06-27  2024-06-27           0
# 5             saloni1148   2024-06-16  2024-06-16           0
# 6              bose19942   2024-06-05  2024-06-05           0
# 7      swarnimsrijan7470   2024-05-16  2024-05-16           0
# 8       deepasinghal4729   2024-05-13  2024-05-13           0
# 9        rahulrajeev9763   2024-04-27  2024-04-27           0
# 10         mohdsaqib3241   2024-04-27  2024-04-27           0
# 11        yankoshuan6225   2024-04-20  2024-04-20           0
# 12       user-uv5lr7bk8n   2024-04-18  2024-04-18           0
# 13            najam00717   2024-04-01  2024-04-01           0
# 14             Abutturab   2024-03-28  2024-03-28           0
# 15             ryang8192   2024-03-21  2024-03-21           1
# 16      VARUNKUMAR-dj6mi   2024-03-04  2024-03-04           0
# 18      VARUNKUMAR-dj6mi   2024-03-04  2024-03-04           0
# 19    internetmaxvui7719   2024-02-28  2024-02-28           0
# 20       vigneshnesh7353   2024-02-22  2024-02-22           0
#
#                                                  text
# 0   hello sir i have tried through the methods u h...
# 1   i am getting key error for the commentcount co...
# 2   can someone tell me from where i can get the s...
# 3                                        this is good
# 4   thank you for putting this together it was sup...
# 5               can i do this project on google colab
# 6                            thank you for this video
# 7   what a brilliant lecture really impressed by y...
# 8        followed till 1814 no error returned nothing
# 9                    thank you so much for this stuff
# 10                           project link not working
# 11  i get only this out from json formatter techtf...
# 12  for a nontech background like me your tutorial...
# 13                  why the json is not showing likes
# 14                                                top
# 15  hello i want to ask how to receive video data ...
# 16  5445 in my scrapping i didint have snippet tit...
# 18  5445 in my scrapping i didint have snippet tit...
# 19  sorry sir the link project in the description ...
# 20              bro project download link not working
